# %% [markdown]
# ### Don't stress, use Python
#
# stress_geotechTools.ipynb - Copyright 2024 S.M.Arndt, Cavroc Pty Ltd
# Visit **https://cavroc.com/** for more information on **IUCM** and **StopeX**
#
# This file is part of [geotechTools](https://github.com/SMArndt/geotechTools). geotechTools is free software: you can redistribute it and/or modify it under the terms of the GNU General Public License as published by the Free Software Foundation. geotechTools is distributed in the hope that it will be useful, but WITHOUT ANY WARRANTY; without even the implied warranty of MERCHANTABILITY or FITNESS FOR A PARTICULAR PURPOSE. See the GNU General Public License for more details. You should have received a copy of the GNU General Public License along with geotechTools. If not, see https://www.gnu.org/licenses/.

# %%
# ---------------------------------------------------------------------------
# imports
# ---------------------------------------------------------------------------

from xyzData import *
from gridData import *
from plot3D import *

# %%
# ---------------------------------------------------------------------------
# example: read stress from file, perform eigenvalue analysis, plot S1
# ---------------------------------------------------------------------------

# read x,y,z data with stress columns
x = xyzData(r'regular_stress.csv')
print(x.index)
# Out:
# reading column headers ...
# x listed in column 0 stored in 0
# y listed in column 1 stored in 1
# z listed in column 2 stored in 2
# colour-xz unlisted in column 3 stored in 3
# colour-yz unlisted in column 4 stored in 4
# colour-xy unlisted in column 5 stored in 5
# sxx unlisted in column 6 stored in 6
# syy unlisted in column 7 stored in 7
# szz unlisted in column 8 stored in 8
# sxy unlisted in column 9 stored in 9
# sxz unlisted in column 10 stored in 10
# syz unlisted in column 11 stored in 11
# time: 0.00299072265625 seconds
# 513 Lines, 12 columns
# invalid data in 0 lines
# {'x': 0, 'y': 1, 'z': 2, 'colour-xz': 3, 'colour-yz': 4, 'colour-xy': 5, 'sxx': 6, 'syy': 7, 'szz': 8, 'sxy': 9, 'sxz': 10, 'syz': 11}

# %%
# extract stress components using the new method extractStress()
stress=x.extractStress(indices='xyz')

# %%
# perform eigenvalue analysis
eigens=[]
for s in stress:
    T=np.array([[s[0],s[3],s[4]],[s[3],s[1],s[5]],[s[4],s[5],s[2]]])
    e_val, e_vec = np.linalg.eig(T)
    e_val.sort()
    eigens.append(e_val[0]) # S1

# %%
# quick way to plot S1 (in last column, t.shape[1]-1)
t=np.hstack((x.current,np.array(eigens).reshape(-1,1)))
plot3D(t,t.shape[1]-1)
# Out:
# elev 12.5, azim -22.5

# %% [markdown]
# [Python gridData in geotechTools](https://www.linkedin.com/pulse/python-griddata-geotechtools-stephan-arndt-kfrkc)
